# %%
import numpy as np
import pandas as pd
import random
from deap import base, creator, tools, algorithms
import matplotlib.pyplot as plt

# Load and preprocess data
data = pd.read_csv('dataset.csv')
data = data.drop_duplicates(keep=False)
price = data['Close'].values  # Only extracting the 'Close' price data
# Print the columns of the DataFrame to verify column names
print(data.columns)
# Constants for harmonic patterns
err_allowed = 10.0 / 100
population_size = 100
num_generations = 50
mutation_prob = 0.2
crossover_prob = 0.5
# Define placeholder functions for harmonic pattern checking
def is_Gartley(moves, err_allowed):
    # Placeholder logic to simulate pattern checking
    # Replace with actual logic for checking Gartley pattern
    return abs(moves[0] - moves[1]) < err_allowed

def is_Butterfly(moves, err_allowed):
    # Placeholder logic to simulate pattern checking
    # Replace with actual logic for checking Butterfly pattern
    return abs(moves[1] - moves[2]) < err_allowed

def is_Bat(moves, err_allowed):
    # Placeholder logic to simulate pattern checking
    # Replace with actual logic for checking Bat pattern
    return abs(moves[2] - moves[3]) < err_allowed

def is_Crab(moves, err_allowed):
    # Placeholder logic to simulate pattern checking
    # Replace with actual logic for checking Crab pattern
    return abs(moves[3] - moves[0]) < err_allowed

# Define pattern checking functions
def pattern_fitness(moves):
    # Placeholder functions for checking harmonic patterns
    gartley = is_Gartley(moves, err_allowed)
    butterfly = is_Butterfly(moves, err_allowed)
    bat = is_Bat(moves, err_allowed)
    crab = is_Crab(moves, err_allowed)

    # Fitness score based on pattern match
    if gartley:
        return 1
    elif butterfly:
        return 1
    elif bat:
        return 1
    elif crab:
        return 1
    else:
        return 0

# Define the fitness evaluation function
def evaluate(individual):
    XA, AB, BC, CD = individual
    moves = [XA, AB, BC, CD]
    return pattern_fitness(moves),

# Genetic Algorithm setup using DEAP
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, -1.0, 1.0)  # Range for each parameter
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, 4)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxBlend, alpha=0.5)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.1, indpb=mutation_prob)
toolbox.register("select", tools.selTournament, tournsize=3)

# Run the Genetic Algorithm
def main():
    pop = toolbox.population(n=population_size)
    hof = tools.HallOfFame(1)

    algorithms.eaSimple(pop, toolbox, cxpb=crossover_prob, mutpb=mutation_prob, ngen=num_generations, 
                        stats=None, halloffame=hof, verbose=False)

    return hof[0]  # Best individual

best_params = main()
print("Best harmonic pattern parameters found:", best_params)

# Visualize the result
# Mock detected points based on the best parameters (if a pattern is matched)
if evaluate(best_params)[0] == 1:
    detected_points = [10, 20, 30, 40, 50]  # Mock indices for example
    pattern_points = price[detected_points]

    plt.figure(figsize=(10, 6))
    plt.plot(price, label="Price Series")
    plt.scatter(detected_points, pattern_points, color="red", label="Detected Pattern")
    plt.title("Harmonic Pattern Detected using Genetic Algorithm")
    plt.xlabel("Index")
    plt.ylabel("Price")
    plt.legend()
    plt.show()
else:
    print("No harmonic pattern detected.")
# Out:
# Index(['Date', 'Close', ' Volume', ' Open', ' High', ' Low'], dtype='object')
# Best harmonic pattern parameters found: [-0.6414718225024234, -0.9883146807454284, -0.3670212889370563, -0.7340609119938697]

# %%
import numpy as np
import pandas as pd
import random
from deap import base, creator, tools, algorithms
import plotly.graph_objs as go
from plotly.offline import plot

# Load and preprocess data
data = pd.read_csv('dataset.csv')
data = data.drop_duplicates(keep=False)
price = data['Close'].values  # Only extracting the 'Close' price data
# Print the columns of the DataFrame to verify column names
print(data.columns)
# Constants for harmonic patterns
err_allowed = 10.0 / 100
population_size = 100
num_generations = 50
mutation_prob = 0.2
crossover_prob = 0.5
# Define placeholder functions for harmonic pattern checking
def is_Gartley(moves, err_allowed):
    # Placeholder logic to simulate pattern checking
    # Replace with actual logic for checking Gartley pattern
    return abs(moves[0] - moves[1]) < err_allowed

def is_Butterfly(moves, err_allowed):
    # Placeholder logic to simulate pattern checking
    # Replace with actual logic for checking Butterfly pattern
    return abs(moves[1] - moves[2]) < err_allowed

def is_Bat(moves, err_allowed):
    # Placeholder logic to simulate pattern checking
    # Replace with actual logic for checking Bat pattern
    return abs(moves[2] - moves[3]) < err_allowed

def is_Crab(moves, err_allowed):
    # Placeholder logic to simulate pattern checking
    # Replace with actual logic for checking Crab pattern
    return abs(moves[3] - moves[0]) < err_allowed

# Define pattern checking functions
def pattern_fitness(moves):
    # Placeholder functions for checking harmonic patterns
    gartley = is_Gartley(moves, err_allowed)
    butterfly = is_Butterfly(moves, err_allowed)
    bat = is_Bat(moves, err_allowed)
    crab = is_Crab(moves, err_allowed)

    # Fitness score based on pattern match
    if gartley:
        return 1
    elif butterfly:
        return 1
    elif bat:
        return 1
    elif crab:
        return 1
    else:
        return 0

# Define the fitness evaluation function
def evaluate(individual):
    XA, AB, BC, CD = individual
    moves = [XA, AB, BC, CD]
    return pattern_fitness(moves),

# Genetic Algorithm setup using DEAP
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, -1.0, 1.0)  # Range for each parameter
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, 4)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxBlend, alpha=0.5)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.1, indpb=mutation_prob)
toolbox.register("select", tools.selTournament, tournsize=3)

# Run the Genetic Algorithm
def main():
    pop = toolbox.population(n=population_size)
    hof = tools.HallOfFame(1)

    algorithms.eaSimple(pop, toolbox, cxpb=crossover_prob, mutpb=mutation_prob, ngen=num_generations, 
                        stats=None, halloffame=hof, verbose=False)

    return hof[0]  # Best individual

best_params = main()
print("Best harmonic pattern parameters found:", best_params)

# Visualize the result using Plotly
# Mock detected points based on the best parameters (if a pattern is matched)
if evaluate(best_params)[0] == 1:
    detected_points = [10, 20, 30, 40, 50]  # Mock indices for example
    pattern_points = price[detected_points]

    # Create the price series trace
    trace_price = go.Scatter(
        x=list(range(len(price))),
        y=price,
        mode='lines',
        name='Price Series'
    )

    # Create the detected pattern trace
    trace_pattern = go.Scatter(
        x=detected_points,
        y=pattern_points,
        mode='markers',
        marker=dict(color='red', size=10),
        name='Detected Pattern'
    )

    # Create the layout
    layout = go.Layout(
        title='Harmonic Pattern Detected using Genetic Algorithm',
        xaxis=dict(title='Index'),
        yaxis=dict(title='Price')
    )

    # Create the figure
    fig = go.Figure(data=[trace_price, trace_pattern], layout=layout)

    # Plot the figure
    plot(fig)
else:
    print("No harmonic pattern detected.")
# Out:
# Index(['Date', 'Close', 'Volume', 'Open', 'High', 'Low'], dtype='object')
# Best harmonic pattern parameters found: [0.4838372193667184, -0.5563868254855651, 0.4217231065521234, 0.5533480706402492]
# C:\Users\vvnsr\anaconda3\Lib\site-packages\deap\creator.py:185: RuntimeWarning:
#
# A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#
# C:\Users\vvnsr\anaconda3\Lib\site-packages\deap\creator.py:185: RuntimeWarning:
#
# A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import mplfinance as mpf

# Ensure 'Date' column is in datetime format
#data['Date'] = pd.to_datetime(data['Date'])
# Specify the date format if consistent
data['Date'] = pd.to_datetime(data['Date'], format="%d-%m-%Y", errors='coerce')
data['Open'] = data['Open'].replace('[\$,]', '', regex=True).astype(float)
data['High'] = data['High'].replace('[\$,]', '', regex=True).astype(float)
data['Low'] = data['Low'].replace('[\$,]', '', regex=True).astype(float)
data['Close'] = data['Close'].replace('[\$,]', '', regex=True).astype(float)


# Set 'Date' as the index for candlestick plotting
data.set_index('Date', inplace=True)
# Remove dollar signs and other non-numeric characters, and convert to float

# Create a custom style for the candlestick chart
custom_style = mpf.make_mpf_style(base_mpf_style='classic', rc={'font.size': 10})

# Define the marker properties for detected pattern points
add_plot = [mpf.make_addplot(price[detected_points], type='scatter', markersize=100, marker='^', color='red')]

# Plot the candlestick chart with highlighted pattern points
mpf.plot(data, type='candle', style=custom_style, addplot=add_plot, title="Harmonic Pattern Detection",
         ylabel="Price", volume=True, show_nontrading=False)
# Out:
# <>:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:14: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:15: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:16: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:14: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:15: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:16: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\vvnsr\AppData\Local\Temp\ipykernel_21252\2738526983.py:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\vvnsr\AppData\Local\Temp\ipykernel_21252\2738526983.py:14: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\vvnsr\AppData\Local\Temp\ipykernel_21252\2738526983.py:15: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\vvnsr\AppData\Local\Temp\ipykernel_21252\2738526983.py:16: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# ...
